# %%
import scipy.stats as sts
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'svg'

# %%
a = 601
b = 401
x = np.arange(0.01, 1, 0.001)
y = sts.beta.pdf(x,a,b)
plt.plot(x,y,label = r'action 1:$\alpha = {a};\beta = {b}$'.format(a=a,b=b))
a = 401
b = 601
x = np.arange(0.01, 1, 0.001)
y = sts.beta.pdf(x,a,b)
plt.plot(x,y,label = r'action 2:$\alpha = {a};\beta = {b}$'.format(a=a,b=b))
a = 2
b = 3
x = np.arange(0.01, 1, 0.001)
y = sts.beta.pdf(x,a,b)
plt.plot(x,y,label = r'action 3:$\alpha = {a};\beta = {b}$'.format(a=a,b=b))
plt.xlim([0,1])
plt.ylim(bottom = 0)
plt.legend()
