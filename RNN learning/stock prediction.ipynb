# %% [markdown]
# # 有点难，先弄点别的

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
import torchvision.datasets as dsets
import torchvision.transforms as transforms


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
use_cuda = True
device = torch.device('cuda:4' if use_cuda else 'cpu')

# %% [markdown]
# # 0、data preprocessing

# %%
dataPath = 'data/battlefin-s-big-data-combine-forecasting-challenge'
trainLabelPath = dataPath + '/trainLabels.csv'
trainDataPath = dataPath + '/data'

# %%
trainLabel = pd.read_csv(trainLabelPath)
trainLabel
# Out:
#      FileId    O1    O2    O3    O4    O5    O6    O7    O8    O9  ...  O189  \
# 0         1  2.53  1.03  0.12  0.01  0.07  0.88  1.30  1.82  2.13  ... -0.65
# 1         2 -4.95  0.18 -0.24 -0.04 -0.49  0.68  0.80  0.64  0.92  ...  0.14
# 2         3  0.16  0.00  0.20 -0.20 -0.11  0.76  0.88  0.18  0.45  ...  0.33
# 3         4  4.43  0.06 -0.20 -0.45 -0.62  0.13  4.35  1.47  0.36  ... -0.27
# 4         5  0.76  0.11  0.12  0.08 -0.25  0.12 -0.44  0.60  0.11  ...  0.20
# ..      ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 195     196 -3.76 -0.06  0.00  0.07 -0.17  0.23 -1.01 -1.07 -0.26  ... -0.02
# 196     197  1.85  1.08  0.20 -0.11  0.47  1.33  1.33  1.53  1.50  ... -0.59
# 197     198 -1.02  1.53  0.62  0.01  1.33  1.15  1.22  2.26  2.25  ... -0.69
# 198     199  0.43  0.12 -0.08  0.22 -0.24 -0.32 -0.73  0.16 -0.65  ... -0.54
# 199     200  0.11  0.00  0.29 -0.18  0.91  0.64  0.68  0.40  0.98  ...  0.39
#
# ...

# %%
class trainData(torch.utils.data.Dataset):
    def __init__(self, dataPath):
        self.dataPath = dataPath
        self.trainLabelPath = dataPath + '/trainLabels.csv'
        self.trainDataPath = dataPath + '/data'

# %%
def getTrainLabel(name):
    data =
# Out:
# (200, 199)
